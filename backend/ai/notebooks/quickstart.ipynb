# %% [markdown]
# # SentinelX AI quickstart
# Generate synthetic data and exercise the replaceable inference pipelines.

# %%
from ai.synthetic_data.generate import generate_all
generate_all()

# %%
from ai.inference.scam import ScamDetectionPipeline
result = await ScamDetectionPipeline().predict('+919999900000', 'I am calling from CBI. Transfer immediately.', 400, True, 4, True)
result.to_dict()
